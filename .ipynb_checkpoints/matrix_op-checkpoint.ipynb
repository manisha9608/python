# %% [markdown]
# # MATRIX OPERATIONS

# %%
import numpy as np;

# %%
A = np.random.randint(1,10, size=(3,5))
A
# Out:
# array([[4, 6, 2, 8, 6],
#        [9, 6, 1, 9, 5],
#        [2, 4, 4, 7, 9]])

# %% [markdown]
# ## Transpose

# %%
np.transpose(A)
# Out:
# array([[4, 9, 2],
#        [6, 6, 4],
#        [2, 1, 4],
#        [8, 9, 7],
#        [6, 5, 9]])

# %%
B = np.random.randint(1,10, size=(3,5))
B
# Out:
# array([[6, 2, 6, 1, 3],
#        [2, 7, 8, 9, 5],
#        [9, 9, 1, 5, 3]])

# %% [markdown]
# ## Arithmetic Operations

# %%
A+B
# Out:
# array([[10,  8,  8,  9,  9],
#        [11, 13,  9, 18, 10],
#        [11, 13,  5, 12, 12]])

# %%
A
# Out:
# array([[4, 6, 2, 8, 6],
#        [9, 6, 1, 9, 5],
#        [2, 4, 4, 7, 9]])

# %%
B
# Out:
# array([[6, 2, 6, 1, 3],
#        [2, 7, 8, 9, 5],
#        [9, 9, 1, 5, 3]])

# %%
A+B
# Out:
# array([[10,  8,  8,  9,  9],
#        [11, 13,  9, 18, 10],
#        [11, 13,  5, 12, 12]])

# %%
A-B
# Out:
# array([[-2,  4, -4,  7,  3],
#        [ 7, -1, -7,  0,  0],
#        [-7, -5,  3,  2,  6]])

# %%
A*B
# Out:
# array([[24, 12, 12,  8, 18],
#        [18, 42,  8, 81, 25],
#        [18, 36,  4, 35, 27]])

# %%
A
# Out:
# array([[4, 6, 2, 8, 6],
#        [9, 6, 1, 9, 5],
#        [2, 4, 4, 7, 9]])

# %% [markdown]
# ## Matrix Multiplication

# %%
A #3*5
# Out:
# array([[4, 6, 2, 8, 6],
#        [9, 6, 1, 9, 5],
#        [2, 4, 4, 7, 9]])

# %%
C = np.random.randint(1, 10, size=(5,3))
C
# Out:
# array([[7, 2, 5],
#        [6, 5, 9],
#        [6, 6, 7],
#        [4, 2, 7],
#        [8, 7, 8]])

# %%
A.shape
# Out:
# (3, 5)

# %%
C.shape
# Out:
# (5, 3)

# %%
A.ndim
# Out:
# 2

# %%
C.ndim
# Out:
# 2

# %%
Z = np.cross(A,C)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-0ffac77c2f0f> in <module>
# ----> 1 Z = np.cross(A,C)
#
# <__array_function__ internals> in cross(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in cross(a, b, axisa, axisb, axisc, axis)
#    1547            "(dimension must be 2 or 3)")
#    1548     if a.shape[-1] not in (2, 3) or b.shape[-1] not in (2, 3):
# -> 1549         raise ValueError(msg)
#    1550
#    1551     # Create the output array
#
# ValueError: incompatible dimensions for cross product
# (dimension must be 2 or 3)

# %%
np.dot(A, C)
# Out:
# array([[156, 108, 192],
#        [181, 107, 209],
#        [162, 125, 195]])

# %%
A.dot(C)
# Out:
# array([[156, 108, 192],
#        [181, 107, 209],
#        [162, 125, 195]])

# %% [markdown]
# ## Determinant

# %%
np.det(A)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-e99f0215d6b9> in <module>
# ----> 1 np.det(A)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/__init__.py in __getattr__(attr)
#     218             else:
#     219                 raise AttributeError("module {!r} has no attribute "
# --> 220                                      "{!r}".format(__name__, attr))
#     221
#     222         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'det'

# %%
np.linalg.det(A)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-30-d6ff28f11825> in <module>
# ----> 1 np.linalg.det(A)
#
# <__array_function__ internals> in det(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in det(a)
#    2111     a = asarray(a)
#    2112     _assert_stacked_2d(a)
# -> 2113     _assert_stacked_square(a)
#    2114     t, result_t = _commonType(a)
#    2115     signature = 'D->D' if isComplexType(t) else 'd->d'
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in _assert_stacked_square(*arrays)
#     211         m, n = a.shape[-2:]
#     212         if m != n:
# --> 213             raise LinAlgError('Last 2 dimensions of the array must be square')
#     214
#     215 def _assert_finite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
D = np.random.randint(1,5, size=(2,2))
D
# Out:
# array([[2, 1],
#        [1, 4]])

# %%
np.linalg.det(D)
# Out:
# 7.000000000000001

# %%
E = np.random.randint(1,5, size=(3,3))
E
# Out:
# array([[4, 4, 1],
#        [4, 1, 2],
#        [4, 2, 4]])

# %%
np.linalg.det(E)
# Out:
# -28.00000000000001

# %% [markdown]
# ## Inverse

# %%
np.linalg.inv(D)
# Out:
# array([[ 0.57142857, -0.14285714],
#        [-0.14285714,  0.28571429]])

# %%
np.linalg.inv(E)
# Out:
# array([[ 0.        ,  0.5       , -0.25      ],
#        [ 0.28571429, -0.42857143,  0.14285714],
#        [-0.14285714, -0.28571429,  0.42857143]])

# %% [markdown]
# ## Matrix Rank

# %%
F = np.array([[1,2,-1,-2,0], [2,4,-1,1,0], [3,6,-1,4,1], [0,0,1,5,0]])
F
# Out:
# array([[ 1,  2, -1, -2,  0],
#        [ 2,  4, -1,  1,  0],
#        [ 3,  6, -1,  4,  1],
#        [ 0,  0,  1,  5,  0]])

# %%
np.linalg.matrix_rank(F)
# Out:
# 3
