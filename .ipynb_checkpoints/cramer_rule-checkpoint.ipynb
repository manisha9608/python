# %% [markdown]
# # Cramer's rule

# %%
import numpy as np

# %%
# 3x1 + x2 = 4
# 2x1 + x2 = 3

# %%
A = np.array([[3,1], [2,1]])
B = np.array([4,3])
A
# Out:
# array([[3, 1],
#        [2, 1]])

# %%
detA = np.linalg.det(A)
detA
# Out:
# 1.0000000000000002

# %%
# Replace first column
C = np.copy(A)
C[:, 0] = B
C
# Out:
# array([[4, 1],
#        [3, 1]])

# %%
A
# Out:
# array([[3, 1],
#        [2, 1]])

# %%
x1 = np.linalg.det(C)/detA
x1
# Out:
# 0.9999999999999998

# %%
C = np.copy(A)
C[:, 1] = B
C
# Out:
# array([[3, 4],
#        [2, 3]])

# %%
A
# Out:
# array([[3, 1],
#        [2, 1]])

# %%
x2 = np.linalg.det(C)/detA
x2
# Out:
# 1.0000000000000002
